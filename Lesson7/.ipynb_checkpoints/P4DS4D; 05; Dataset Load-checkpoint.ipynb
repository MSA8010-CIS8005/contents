# %% [markdown]
# # Uploading, Streaming, and Sampling Data

# %% [markdown]
# ## Uploading small amounts of data into memory

# %%
with open("Colors.txt", 'r') as open_file:
    print 'Colors.txt content:\n' + open_file.read()
# Out:
# Colors.txt content:
# Color	Value
# Red	1
# Orange	2
# Yellow	3
# Green	4
# Blue	5
# Purple	6
# Black	7
# White	8

# %%
# same example but reading only 10 characters
with open("Colors.txt", 'r') as open_file:
    print 'Colors.txt content:\n' + open_file.read(11)
# Out:
# Colors.txt content:
# Color	Value

# %% [markdown]
# ## Streaming large amounts of data into memory
#
# Some datasets will be so large that you wont be able fit them entirely in memory at one time. In addition, you may find that some datasets load slowly because they reside on a remote site. Streaming answers both needs by making it possible to work with data a little at a time.

# %%
with open("Colors.txt", 'r') as open_file:
    for observation in open_file:
        # this is Pythin 2 so end cannot be used. The , at the end means suppress newline
        print 'Reading Data: ' + observation,
# Out:
# Reading Data: Color	Value
# Reading Data: Red	1
# Reading Data: Orange	2
# Reading Data: Yellow	3
# Reading Data: Green	4
# Reading Data: Blue	5
# Reading Data: Purple	6
# Reading Data: Black	7
# Reading Data: White	8

# %% [markdown]
# ## Sampling data
#
# Data streaming obtains all the records from a data source. You may find that you dont need all the records. You can save time and resources by simply sampling the data.

# %% [markdown]
# ### Fixed samples
# This example samples every other record.

# %%
''' 
enumerate is built in Python function, example:

seasons = ['Spring', 'Summer', 'Fall', 'Winter']
list(enumerate(seasons))
[(0, 'Spring'), (1, 'Summer'), (2, 'Fall'), (3, 'Winter')]

'''
n = 3
with open("Colors.txt", 'rb') as open_file:
    for j, observation in enumerate(open_file):
        if j % n==0:
            print('Reading Line: ' + str(j) + 
            ' Content: ' + observation)
# Out:
# Reading Line: 0 Content: Color	Value
#
# Reading Line: 3 Content: Yellow	3
#
# Reading Line: 6 Content: Purple	6

# %% [markdown]
# ### Random samples
# You can perform random sampling as well. All you need to do is randomize the selector.

# %%
from random import random
sample_size = 0.25
with open("Colors.txt", 'rb') as open_file:
    for j, observation in enumerate(open_file):
        if random()<=sample_size:
            print('Reading Line: ' + str(j) + 
            ' Content: ' + observation)
# Out:
# Reading Line: 2 Content: Orange	2
#
# Reading Line: 4 Content: Green	4
#
# Reading Line: 6 Content: Purple	6

# %% [markdown]
# # Accessing Data in Structured Flat File Form
#
# A problem with using native Python techniques is that the input isnt intelligent. For example, when a file contains a header, Python simply reads it as yet more data to process, rather than as a header.

# %% [markdown]
# ## Reading from a text file

# %%
import pandas as pd
color_table = pd.io.parsers.read_table("Colors.txt")
print color_table
# Out:
#     Color  Value
# 0     Red      1
# 1  Orange      2
# 2  Yellow      3
# 3   Green      4
# 4    Blue      5
# 5  Purple      6
# 6   Black      7
# 7   White      8

# %% [markdown]
# ## Reading CSV delimited format

# %%
import pandas as pd
titanic = pd.io.parsers.read_csv("Titanic.csv")
type(titanic)
# Out:
# pandas.core.frame.DataFrame

# %%
titanic
# Out:
#       Unnamed: 0 pclass  survived     sex        age  sibsp  parch
# 0              1    1st  survived  female    29.0000      0      0
# 1              2    1st  survived    male     0.9167      1      2
# 2              3    1st      died  female     2.0000      1      2
# 3              4    1st      died    male    30.0000      1      2
# 4              5    1st      died  female    25.0000      1      2
# 5              6    1st  survived    male    48.0000      0      0
# 6              7    1st  survived  female    63.0000      1      0
# 7              8    1st      died    male    39.0000      0      0
# 8              9    1st  survived  female    53.0000      2      0
# 9             10    1st      died    male    71.0000      0      0
# 10            11    1st      died    male    47.0000      1      0
# 11            12    1st  survived  female    18.0000      1      0
# 12            13    1st  survived  female    24.0000      0      0
# 13            14    1st  survived  female    26.0000      0      0
# 14            15    1st  survived    male    80.0000      0      0
# 15            16    1st      died    male  9999.0000      0      0
# 16            17    1st      died    male    24.0000      0      1
# 17            18    1st  survived  female    50.0000      0      1
# 18            19    1st  survived  female    32.0000      0      0
# 19            20    1st      died    male    36.0000      0      0
# 20            21    1st  survived    male    37.0000      1      1
# 21            22    1st  survived  female    47.0000      1      1
# 22            23    1st  survived    male    26.0000      0      0
# 23            24    1st  survived  female    42.0000      0      0
# 24            25    1st  survived  female    29.0000      0      0
# 25            26    1st      died    male    25.0000      0      0
# 26            27    1st  survived    male    25.0000      1      0
# 27            28    1st  survived  female    19.0000      1      0
# 28            29    1st  survived  female    35.0000      0      0
# 29            30    1st  survived    male    28.0000      0      0
# ...          ...    ...       ...     ...        ...    ...    ...
# 1279        1280    3rd      died  female    14.0000      0      0
# 1280        1281    3rd      died    male    22.0000      0      0
# 1281        1282    3rd      died    male    22.0000      0      0
# 1282        1283    3rd      died    male  9999.0000      0      0
# 1283        1284    3rd      died    male  9999.0000      0      0
# 1284        1285    3rd      died    male  9999.0000      0      0
# 1285        1286    3rd      died    male    32.5000      0      0
# 1286        1287    3rd  survived  female    38.0000      0      0
# 1287        1288    3rd      died    male    51.0000      0      0
# 1288        1289    3rd      died    male    18.0000      1      0
# 1289        1290    3rd      died    male    21.0000      1      0
# 1290        1291    3rd  survived  female    47.0000      1      0
# 1291        1292    3rd      died    male  9999.0000      0      0
# 1292        1293    3rd      died    male  9999.0000      0      0
# 1293        1294    3rd      died    male  9999.0000      0      0
# 1294        1295    3rd      died    male    28.5000      0      0
# 1295        1296    3rd      died    male    21.0000      0      0
# 1296        1297    3rd      died    male    27.0000      0      0
# 1297        1298    3rd      died    male  9999.0000      0      0
# 1298        1299    3rd      died    male    36.0000      0      0
# 1299        1300    3rd      died    male    27.0000      1      0
# 1300        1301    3rd  survived  female    15.0000      1      0
# 1301        1302    3rd      died    male    45.5000      0      0
# 1302        1303    3rd      died    male  9999.0000      0      0
# 1303        1304    3rd      died    male  9999.0000      0      0
# 1304        1305    3rd      died  female    14.5000      1      0
# 1305        1306    3rd      died  female  9999.0000      1      0
# 1306        1307    3rd      died    male    26.5000      0      0
# 1307        1308    3rd      died    male    27.0000      0      0
# 1308        1309    3rd      died    male    29.0000      0      0
#
# [1309 rows x 7 columns]

# %%
titanic[['age']] # you can execute titanic['age'] and gives you a Series
# Out:
#             age
# 0       29.0000
# 1        0.9167
# 2        2.0000
# 3       30.0000
# 4       25.0000
# 5       48.0000
# 6       63.0000
# 7       39.0000
# 8       53.0000
# 9       71.0000
# 10      47.0000
# 11      18.0000
# 12      24.0000
# 13      26.0000
# 14      80.0000
# 15    9999.0000
# 16      24.0000
# 17      50.0000
# 18      32.0000
# 19      36.0000
# 20      37.0000
# 21      47.0000
# 22      26.0000
# 23      42.0000
# 24      29.0000
# 25      25.0000
# 26      25.0000
# 27      19.0000
# 28      35.0000
# 29      28.0000
# ...         ...
# 1279    14.0000
# 1280    22.0000
# 1281    22.0000
# 1282  9999.0000
# 1283  9999.0000
# 1284  9999.0000
# 1285    32.5000
# 1286    38.0000
# 1287    51.0000
# 1288    18.0000
# 1289    21.0000
# 1290    47.0000
# 1291  9999.0000
# 1292  9999.0000
# 1293  9999.0000
# 1294    28.5000
# 1295    21.0000
# 1296    27.0000
# 1297  9999.0000
# 1298    36.0000
# 1299    27.0000
# 1300    15.0000
# 1301    45.5000
# 1302  9999.0000
# 1303  9999.0000
# 1304    14.5000
# 1305  9999.0000
# 1306    26.5000
# 1307    27.0000
# 1308    29.0000
#
# [1309 rows x 1 columns]

# %%
titanic[['age', 'sex']].sort('age')
# Out:
#             age     sex
# 763      0.1667  female
# 747      0.3333    male
# 1240     0.4167    male
# 427      0.6667    male
# 657      0.7500  female
# 658      0.7500  female
# 1111     0.7500    male
# 611      0.8333    male
# 548      0.8333    male
# 359      0.8333    male
# 590      0.9167  female
# 1        0.9167    male
# 339      1.0000    male
# 1101     1.0000    male
# 762      1.0000    male
# 937      1.0000  female
# 826      1.0000    male
# 895      1.0000  female
# 1048     1.0000  female
# 1187     1.0000  female
# 492      1.0000    male
# 478      1.0000  female
# 1230     2.0000  female
# 1156     2.0000  female
# 624      2.0000  female
# 1144     2.0000    male
# 1096     2.0000    male
# 1209     2.0000  female
# 1103     2.0000    male
# 866      2.0000  female
# ...         ...     ...
# 962   9999.0000    male
# 961   9999.0000  female
# 1109  9999.0000    male
# 958   9999.0000  female
# 957   9999.0000  female
# 108   9999.0000  female
# 107   9999.0000  female
# 1114  9999.0000    male
# 1115  9999.0000    male
# 1116  9999.0000    male
# 106   9999.0000    male
# 955   9999.0000  female
# 954   9999.0000    male
# 184   9999.0000    male
# 204   9999.0000  female
# 196   9999.0000    male
# 1132  9999.0000    male
# 940   9999.0000    male
# 942   9999.0000    male
# 944   9999.0000    male
# 1033  9999.0000    male
# 1128  9999.0000    male
# 946   9999.0000    male
# 948   9999.0000    male
# 1124  9999.0000  female
# 1123  9999.0000  female
# 1122  9999.0000  female
# 1121  9999.0000    male
# 945   9999.0000    male
# 956   9999.0000  female
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## Reading Excel and other Microsoft Office files

# %%
import pandas as pd
xls = pd.ExcelFile("Values.xls")
# The index column is the one that the worksheet uses to index the records. Using value of None means 
# that panda should generate an index for you.
trig_values = xls.parse('Sheet1', index_col=None, na_values=['NA'])

# you can do it in one shot as follows:
#trig_values = pd.read_excel("Values.xls", 'Sheet1', na_values=['NA'])
trig_values
# Out:
#     Angle (Degrees)      Sine    Cosine    Tangent
# 0        138.550574  0.661959 -0.749540  -0.883153
# 1        305.535745 -0.813753  0.581211  -1.400100
# 2        280.518695 -0.983195  0.182556  -5.385709
# 3        216.363795 -0.592910 -0.805269   0.736289
# 4         36.389247  0.593268  0.805005   0.736974
# 5         31.474311  0.522116  0.852874   0.612184
# 6        120.121669  0.864962 -0.501838  -1.723588
# 7        293.947055 -0.913921  0.405892  -2.251634
# 8        179.882632  0.002048 -0.999998  -0.002048
# 9        120.927562  0.857818 -0.513954  -1.669056
# 10        71.349485  0.947487  0.319795   2.962796
# 11       241.971082 -0.882711 -0.469917   1.878439
# 12       297.208817 -0.889346  0.457235  -1.945053
# 13       142.004551  0.615599 -0.788060  -0.781158
# 14       173.770696  0.108508 -0.994096  -0.109152
# 15       229.232002 -0.757360 -0.652998   1.159820
# 16        67.926976  0.926706  0.375788   2.466033
# 17       261.866575 -0.989941 -0.141479   6.997102
# 18        59.185450  0.858830  0.512261   1.676547
# 19        98.029275  0.990197 -0.139679  -7.089086
# 20         9.336088  0.162225  0.986754   0.164403
# 21        90.746371  0.999915 -0.013026 -76.761483
# 22       217.798087 -0.612881 -0.790175   0.775626
# 23        58.616049  0.853697  0.520771   1.639295
# 24       197.196367 -0.295647 -0.955297   0.309482
# 25       331.194892 -0.481832  0.876264  -0.549871
# 26         6.509875  0.113374  0.993552   0.114110
# 27       266.390707 -0.998017 -0.062952  15.853513
# 28       230.323819 -0.769665 -0.638448   1.205525
# 29       314.224257 -0.716615  0.697469  -1.027452
# ..              ...       ...       ...        ...
# 42       324.080564 -0.586647  0.809843  -0.724396
# 43       140.893727  0.630761 -0.775977  -0.812860
# 44       128.226889  0.785567 -0.618777  -1.269547
# 45        82.770054  0.992049  0.125852   7.882680
# 46       303.112455 -0.837600  0.546284  -1.533268
# 47       164.824273  0.261780 -0.965127  -0.271239
# 48       218.829827 -0.627009 -0.779012   0.804878
# 49        28.649593  0.479452  0.877568   0.546341
# 50       349.336296 -0.185044  0.982730  -0.188296
# 51        84.889713  0.996025  0.089073  11.182105
# 52       197.935862 -0.307952 -0.951402   0.323683
# 53       303.049380 -0.838201  0.545362  -1.536963
# 54       183.737235 -0.065181 -0.997873   0.065320
# 55       346.153919 -0.239314  0.970942  -0.246477
# 56       218.822745 -0.626913 -0.779089   0.804674
# 57       243.969070 -0.898557 -0.438856   2.047498
# 58       115.600771  0.901827 -0.432098  -2.087089
# 59       125.906606  0.809974 -0.586466  -1.381111
# 60       200.094363 -0.343567 -0.939128   0.365836
# 61       337.860807 -0.376858  0.926271  -0.406855
# 62       168.176975  0.204889 -0.978785  -0.209330
# 63       305.708155 -0.812000  0.583657  -1.391229
# 64       162.656078  0.298107 -0.954533  -0.312306
# 65       219.007899 -0.629428 -0.777059   0.810012
# 66       222.830465 -0.679831 -0.733368   0.926998
# 67       324.199562 -0.584964  0.811059  -0.721234
# 68       187.948172 -0.138277 -0.990394   0.139619
# 69       270.678249 -0.999930  0.011837 -84.472139
# 70       270.779159 -0.999908  0.013598 -73.530885
# 71       200.213513 -0.345520 -0.938412   0.368196
#
# [72 rows x 4 columns]

# %% [markdown]
# # Sending Data in Unstructured File Form
#
# Unstructured data files consist of series of bits. The file doesnt separate the bits from each other in any way. You cannnot simply look into the file and see any structure because there isnt any to see. Unstructured file formats rely on the file user to know how to interpret the data. For example, each pixel of a picture file could consist of three 32-bit fields. Knowing that each field is 32-bits is up to you.

# %% [markdown]
# ## Rendering the image

# %%
% matplotlib inline
# these are coming from scikit modules
from skimage.io import imread
from skimage.transform import resize 

from matplotlib import pyplot as plt
import matplotlib.cm as cm

example_file = ("http://upload.wikimedia.org/" +
    "wikipedia/commons/7/7d/Dog_face.png")
image = imread(example_file)
plt.imshow(image)
plt.show()

# %% [markdown]
# ## Displaying the image information

# %%
# 90 x 90 and 3 for colors
print("data type: %s, shape: %s" % 
      (type(image), image.shape))
# Out:
# data type: <type 'numpy.ndarray'>, shape: (90, 90, 3)

# %% [markdown]
# ## Cropping the image

# %%
image2 = image[5:70,0:70]
plt.imshow(image2)
plt.show()

# %% [markdown]
# ## Resizing the image

# %%
image3 = resize(image2, (30, 30))
plt.imshow(image3)
print("data type: %s, shape: %s" % 
      (type(image3), image3.shape))
# Out:
# data type: <type 'numpy.ndarray'>, shape: (30, 30, 3)

# %% [markdown]
# ## Flatening the image

# %%
image_row = image3.flatten()
print("data type: %s, shape: %s" % 
      (type(image_row), image_row.shape))
# Out:
# data type: <type 'numpy.ndarray'>, shape: (2700,)

# %% [markdown]
# # Accessing Data from the Web
#
# One of the most beneficial data access techniques to know when working with web data is accessing XML. All sorts of content types rely on XML, even some webpages.

# %%
from lxml import objectify
import pandas as pd

xml = objectify.parse(open('XMLData.xml'))
root = xml.getroot()
df = pd.DataFrame(columns=('Number', 'String', 'Boolean'))

for i in range(0,4):
    obj = root.getchildren()[i].getchildren()
    # zip makes a tuple list of tuples liek [('Number', '1'), ('String', 'First'), ('Boolean', 'True')]
    # dict makes a dictionary of those tuples
    row = dict(zip(['Number', 'String', 'Boolean'], 
                   [obj[0].text, obj[1].text, 
                    obj[2].text]))
    
    row_s = pd.Series(row)
    # name for each row
    row_s.name = i
    df = df.append(row_s)
    
df
# Out:
#   Number  String Boolean
# 0      1   First    True
# 1      2  Second   False
# 2      3   Third    True
# 3      4  Fourth   False
